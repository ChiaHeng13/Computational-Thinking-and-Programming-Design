# %%
print('學習',"Pythin",'真有趣')
# Out:
# 學習 Pythin 真有趣

# %%
name=input("請問貴姓大名?")
print("你好，",name)
# Out:
# 請問貴姓大名?John
# 你好， John

# %%
print("學習Python真有趣")
# Out:
# 學習Python真有趣

# %%
name=input("請問貴姓大名?")
print("你好，",name)
# Out:
# 請問貴姓大名? ChiaHeng
# 你好，  ChiaHeng

# %%
a=1
print(a,id(a))
a="Python"
print(a,id(a))
# Out:
# 1 10968800
# Python 140152934460472

# %%
b=True
print(b,type(b))
num=20
print(num,type(num))
pi=3.14
print(pi,type(pi))
s="Hello"
print(s,type(s))
# Out:
# True <class 'bool'>
# 20 <class 'int'>
# 3.14 <class 'float'>
# Hello <class 'str'>

# %%
print(bool(1))
print(bool(0))
print(bool(()))
# Out:
# True
# False
# False

# %%
print(int(100))
print(int(3.14))
print(int('100',2))
# Out:
# 100
# 3
# 4

# %%
print(float(1))
print(float(3.14))
print(float('3.1415'))
# Out:
# 1.0
# 3.14
# 3.1415

# %%
s=str('Pythin')
s[0]='Q'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-2710c5da8ba3> in <module>()
#       1 s=str('Pythin')
# ----> 2 s[0]='Q'
#
# TypeError: 'str' object does not support item assignment

# %%
A=(5<2)
print(A)

A=(5<=2)
print(A)

A=(5>2)
print(A)

A=(5>=2)
print(A)

A=(5!=2)
print(A)

A=(5==2)
print(A)
# Out:
# False
# False
# True
# True
# True
# False

# %%
x=1
y=[1,2,3]
print(x in y)
# Out:
# True

# %%
x=1
y=[1,2,3]
print(x not in y)
# Out:
# False

# %%
x=[1,2,3]
y=[1,2,3]
print(x is y)
# Out:
# False

# %%
x=[1,2,3]
y=[1,2,3]
print(x is not y)
# Out:
# True

# %%
x=[1,2,3]
y=[1,2,3]
print(id(x),id(y))
print(x is y)
print(x==y)
# Out:
# 140152371963336 140152371946824
# False
# True

# %%
A=5+2
print(A)
# Out:
# 7

# %%
A=5-2
print(A)
# Out:
# 3

# %%
A=5*2

print(A)
# Out:
# 10

# %%
A=5/2

print(A)
# Out:
# 2.5

# %%
A=5//2

print(A)
# Out:
# 2

# %%
A=5%2

print(A)
# Out:
# 1

# %%
A=5**2

print(A)
# Out:
# 25

# %%
a=(2+3*2)*(4-1)

print(a)
# Out:
# 24

# %%
a=5
a=a+1

print(a)
# Out:
# 6

# %%
a=5
a=a-1
print(a)
# Out:
# 4

# %%
pow(2,10)
# Out:
# 1024

# %%
s='春眠不覺曉，處處聞啼鳥。\n\
夜來風雨聲，花落知多少。\n\
\t作者"孟浩然"詩名"春曉"'
print(s)
# Out:
# 春眠不覺曉，處處聞啼鳥。
# 夜來風雨聲，花落知多少。
# 	作者"孟浩然"詩名"春曉"

# %%
s1='春眠不覺曉，處處聞啼鳥，夜來風雨聲，花落知多少。'
list1=s1.split('，')
print(list1)
# Out:
# ['春眠不覺曉', '處處聞啼鳥', '夜來風雨聲', '花落知多少。']

# %%
list1=['春眠不覺曉', '處處聞啼鳥', '夜來風雨聲', '花落知多少。']
s2='，'.join(list1)
print(s2)
# Out:
# 春眠不覺曉，處處聞啼鳥，夜來風雨聲，花落知多少。

# %%
s3=s1.replace('春','冬')
print(s3)
# Out:
# 冬眠不覺曉，處處聞啼鳥，夜來風雨聲，花落知多少。
